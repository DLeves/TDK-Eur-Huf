# %% [markdown]
# # LSTM optimal lag search

# %% [markdown]
# ## Packages

# %%
import numpy as np
import pandas as pd
from lstm_functions import *


from tensorflow.keras.models import Sequential
from tensorflow.keras import layers, callbacks
from tensorflow.keras.optimizers import Adam

from sklearn.metrics import mean_absolute_error, mean_squared_error
from scipy import stats

# %% [markdown]
# ## Reading the data

# %%
df = pd.read_csv('full_dataset_20250830.csv')
df.index = pd.to_datetime(df['Date'])
df
# Out:
#             Unnamed: 0        Date  eur_close    MNB    ECB  mean_kinfo  \
# Date
# 2018-05-31           1  2018-05-31    319.404  0.009  0.000         0.0
# 2018-06-03           2  2018-06-03    319.766  0.009  0.000         0.0
# 2018-06-04           3  2018-06-04    318.491  0.009  0.000         0.0
# 2018-06-05           4  2018-06-05    318.665  0.009  0.000         0.0
# 2018-06-06           5  2018-06-06    317.931  0.009  0.000         0.0
# ...                ...         ...        ...    ...    ...         ...
# 2025-02-10        1746  2025-02-10    403.845  0.065  0.029         0.0
# 2025-02-11        1747  2025-02-11    403.584  0.065  0.029         0.0
# 2025-02-12        1748  2025-02-12    402.856  0.065  0.029         0.0
# 2025-02-13        1749  2025-02-13    401.722  0.065  0.029         0.0
# 2025-02-14        1750  2025-02-14    401.669  0.065  0.029         0.0
#
#             mean_matolcsy  mean_nagy  mean_varga  max_kinfo  max_matolcsy  \
# Date
# ...

# %% [markdown]
# ## Lag 1

# %%
mse_lag_1 = sim_lstm_custom_lag(df = df, y_name = 'eur_close', lag =  1, n_sim= 10)
np.mean(mse_lag_1)
# Out:
# d:\TDK-Eur-Huf\LSTM\lstm_functions.py:160: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   windowed_df = df_to_windowed_df(df[y_name], df['Date'][lag], '2025-02-03', lag)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# np.float64(7.907979393771322)

# %% [markdown]
# ## Lag 2

# %%
mse_lag_2 = sim_lstm_custom_lag(df = df, y_name = 'eur_close', lag =  2, n_sim= 100)
np.mean(mse_lag_2)
# Out:
# d:\TDK-Eur-Huf\LSTM\lstm_functions.py:160: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   windowed_df = df_to_windowed_df(df[y_name], df['Date'][lag], '2025-02-03', lag)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# ...

# %% [markdown]
# ## Lag 3

# %%
mse_lag_3 = sim_lstm_custom_lag(df = df, y_name = 'eur_close', lag =  3, n_sim= 100)
np.mean(mse_lag_3)
# Out:
# d:\TDK-Eur-Huf\LSTM\lstm_functions.py:160: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   windowed_df = df_to_windowed_df(df[y_name], df['Date'][lag], '2025-02-03', lag)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# ...

# %% [markdown]
# ## Lag 4

# %%
mse_lag_4 = sim_lstm_custom_lag(df = df, y_name = 'eur_close', lag =  4, n_sim= 100)
np.mean(mse_lag_4)
# Out:
# d:\TDK-Eur-Huf\LSTM\lstm_functions.py:160: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   windowed_df = df_to_windowed_df(df[y_name], df['Date'][lag], '2025-02-03', lag)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# ...

# %% [markdown]
# ## Lag 5

# %%
mse_lag_5 = sim_lstm_custom_lag(df = df, y_name = 'eur_close', lag =  5, n_sim= 100)
np.mean(mse_lag_5)
# Out:
# d:\TDK-Eur-Huf\LSTM\lstm_functions.py:160: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   windowed_df = df_to_windowed_df(df[y_name], df['Date'][lag], '2025-02-03', lag)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# ...

# %% [markdown]
# ## Lag 6

# %%
mse_lag_6 = sim_lstm_custom_lag(df = df, y_name = 'eur_close', lag =  6, n_sim= 100)
np.mean(mse_lag_6)
# Out:
# d:\TDK-Eur-Huf\LSTM\lstm_functions.py:160: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   windowed_df = df_to_windowed_df(df[y_name], df['Date'][lag], '2025-02-03', lag)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# ...

# %% [markdown]
# ## Lag 7

# %%
mse_lag_7 = sim_lstm_custom_lag(df = df, y_name = 'eur_close', lag =  6, n_sim= 100)
np.mean(mse_lag_7)
# Out:
# d:\TDK-Eur-Huf\LSTM\lstm_functions.py:160: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   windowed_df = df_to_windowed_df(df[y_name], df['Date'][lag], '2025-02-03', lag)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# ...

# %% [markdown]
# ## Lag 8

# %%
mse_lag_8 = sim_lstm_custom_lag(df = df, y_name = 'eur_close', lag =  6, n_sim= 100)
np.mean(mse_lag_8)
# Out:
# d:\TDK-Eur-Huf\LSTM\lstm_functions.py:160: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   windowed_df = df_to_windowed_df(df[y_name], df['Date'][lag], '2025-02-03', lag)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# ...

# %% [markdown]
# ## Lineplot of the lags

# %%
lags = pd.DataFrame(
    {'rmse':[np.mean(mse_lag_1), np.mean(mse_lag_2), np.mean(mse_lag_3), np.mean(mse_lag_4), np.mean(mse_lag_5), np.mean(mse_lag_6),np.mean(mse_lag_7), np.mean(mse_lag_8)]},
    index = (x for x in range(1,9,1))
)

# %%
lags.plot()
# Out:
# <Axes: >

# %%
lags.to_excel("optimal_lag_mean.xlsx", index = False)
